# %% [markdown]
# # Práctica 2 – Aprendizaje Automático II
# ## DQN para el entorno LunarLander-v3
#
# ### Autores
#
# | Nombre | Correo |
# |--------|--------|
# | Julio Lucero | julio.lucero@alumnos.upm.es |
# | Maria Agostina Squillari  | msquillari@alumnos.upm.es |
# | Rocío Márquez  | rocio.marquez@alumnos.upm.es |

# %% [markdown]
# ## Libraries

# %%
# !pip install gymnasium[box2d]

import gymnasium as gym
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import time
import random
import math
# Out:
# zsh:1: no matches found: gymnasium[box2d]

# %% [markdown]
# ## Hyperparameters

# %%
# Learning rate
LEARNING_RATE = 0.0005
# Batch size
BATCH_SIZE = 64
# Discount factor gamma
GAMMA = 0.99
# Size of the replay memory (replay buffer) that saves transitions
MEMORY_SIZE = 100000
# Values related to the exploration rate used by the epsilon-greedy policy
EXPLORATION_RATE_MAX = 1
EXPLORATION_RATE_MIN = 0.01
EXPLORATION_RATE_DECAY = 0.995
# Maximum number of episodes for training
MAX_EPISODES_FOR_TRAINING = 600
# Goal score to be achieved during the training process
TRAINING_GOAL = 200
# Number of episodes used to check the goal score during the training process
EPISODES_TO_CHECK_TRAINING_GOAL = 30
# Number of episodes used to evaluate the model performance after training
EPISODES_TO_EVALUATE_MODEL_PERFORMANCE = 30
# Frequency for updating target network
TARGET_UPDATE_FREQUENCY = 500

# %% [markdown]
# ## Class ReplayMemory
#
# Memory of transitions for experience replay.

# %%
class ReplayMemory:

    def __init__(self, number_of_observations):
        # Create replay memory
        self.states = np.zeros((MEMORY_SIZE, number_of_observations))
        self.states_next = np.zeros((MEMORY_SIZE, number_of_observations))
        self.actions = np.zeros(MEMORY_SIZE, dtype=np.int32)
        self.rewards = np.zeros(MEMORY_SIZE)
        self.terminal_states = np.zeros(MEMORY_SIZE, dtype=bool)
        self.current_size = 0
        self.index = 0

    def store_transition(self, state, action, reward, state_next, terminal_state):
        # Store a transition (s,a,r,s') in the replay memory
        i = self.index
        self.states[i] = state
        self.states_next[i] = state_next
        self.actions[i] = action
        self.rewards[i] = reward
        self.terminal_states[i] = terminal_state

        self.index = (self.index + 1) % MEMORY_SIZE
        self.current_size = min(self.current_size + 1, MEMORY_SIZE)

    def sample_memory(self, batch_size):
        # Generate a sample of transitions from the replay memory
        batch = np.random.choice(self.current_size, batch_size, replace=False)
        states = self.states[batch]
        states_next = self.states_next[batch]
        rewards = self.rewards[batch]
        actions = self.actions[batch]
        terminal_states = self.terminal_states[batch]
        return states, actions, rewards, states_next, terminal_states

# %% [markdown]
# ## Class DQN
#
# Reinforcement learning agent with a Deep Q-Network.

# %%
class DQN:

    def __init__(self, number_of_observations, number_of_actions):
        # Initialize variables and create neural model
        self.number_of_actions = number_of_actions
        self.number_of_observations = number_of_observations
        self.scores = []
        self.memory = ReplayMemory(number_of_observations)
        self.learn_step_counter = 0

        # Main neural model
        self.model = keras.models.Sequential()
        self.model.add(keras.layers.InputLayer(shape=(number_of_observations,)))
        self.model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
        self.model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
        self.model.add(keras.layers.Dense(number_of_actions, activation="linear"))
        self.model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

        # Target neural model
        self.target_model = keras.models.Sequential()
        self.target_model.add(keras.layers.InputLayer(shape=(number_of_observations,)))
        self.target_model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
        self.target_model.add(keras.layers.Dense(128, activation="relu", kernel_initializer="he_normal"))
        self.target_model.add(keras.layers.Dense(number_of_actions, activation="linear"))
        self.target_model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE))

        # Initialize target model with same weights
        self.update_target_network()

    def update_target_network(self):
        self.target_model.set_weights(self.model.get_weights())

    def remember(self, state, action, reward, next_state, terminal_state):
        # Store a tuple (s, a, r, s') for experience replay
        state = np.reshape(state, [self.number_of_observations])
        next_state = np.reshape(next_state, [self.number_of_observations])
        self.memory.store_transition(state, action, reward, next_state, terminal_state)

    def select_epsilon_greedy_policy(self, state, exploration_rate):
        # Generate an action for a given state using epsilon-greedy policy
        if np.random.rand() < exploration_rate:
            return random.randrange(self.number_of_actions)
        else:
            state = np.reshape(state, [1, self.number_of_observations])
            q_values = self.model(state).numpy()
            return np.argmax(q_values[0])

    def select_greedy_policy(self, state):
        # Generate an action for a given state using greedy policy
        state = np.reshape(state, [1, self.number_of_observations])
        q_values = self.model(state).numpy()
        return np.argmax(q_values[0])

    def learn(self):
        # Learn the value Q using a sample of examples from the replay memory
        if self.memory.current_size < BATCH_SIZE:
            return

        states, actions, rewards, next_states, terminal_states = self.memory.sample_memory(BATCH_SIZE)

        q_targets = self.model(states).numpy()
        q_next_states = self.target_model(next_states).numpy()

        for i in range(BATCH_SIZE):
            if terminal_states[i]:
                q_targets[i][actions[i]] = rewards[i]
            else:
                q_targets[i][actions[i]] = rewards[i] + GAMMA * np.max(q_next_states[i])

        self.model.train_on_batch(states, q_targets)

        self.learn_step_counter += 1
        if self.learn_step_counter % TARGET_UPDATE_FREQUENCY == 0:
            self.update_target_network()

    def add_score(self, score):
        # Add the obtained score to a list to be presented later
        self.scores.append(score)

    def delete_scores(self):
        # Delete the scores
        self.scores = []

    def average_score(self, number_of_episodes):
        # Compute average score of the last episodes
        index = len(self.scores) - number_of_episodes
        return np.mean(self.scores[max(0, index):len(self.scores)])

    def display_scores_graphically(self):
        # Display the obtained scores graphically
        plt.plot(self.scores)
        plt.xlabel("Episode")
        plt.ylabel("Score")

    def save_model(self):
        # Save model in format .keras
        self.model.save('my_model.keras')

# %% [markdown]
# ## Auxiliary function

# %%
def print_time(time):
    min = round(time // 60)
    sec = round(time % 60)
    if min > 0:
        print(f"{min} min {sec} seconds")
    else:
        print(f"{sec} seconds")

# %% [markdown]
# ## Environment

# %%
def create_environment():
    # Create simulated environment
    environment = gym.make("LunarLander-v3")
    number_of_observations = environment.observation_space.shape[0]
    number_of_actions = environment.action_space.n
    return environment, number_of_observations, number_of_actions

# %% [markdown]
# ## Program for training

# %%
environment, number_of_observations, number_of_actions = create_environment()
agent = DQN(number_of_observations, number_of_actions)
episode = 0
start_time = time.perf_counter()
total_steps = 0
exploration_rate = EXPLORATION_RATE_MAX
goal_reached = False
while (episode < MAX_EPISODES_FOR_TRAINING) and not(goal_reached):
    episode += 1
    score = 0
    state, info = environment.reset()
    end_episode = False
    while not(end_episode):
        # Select an action for the current state
        action = agent.select_epsilon_greedy_policy(state, exploration_rate)

        # Execute the action on the environment
        state_next, reward, terminal_state, truncated, info = environment.step(action)

        total_steps += 1
        
        done = terminal_state or truncated

        # Store in memory the transition (s,a,r,s')
        agent.remember(state, action, reward, state_next, done)

        score += reward

        # Learn using a batch of experience stored in memory
        agent.learn()

        # Detect end of episode
        if terminal_state or truncated:
            end_episode = True
            agent.add_score(score)
            average_score = agent.average_score(EPISODES_TO_CHECK_TRAINING_GOAL)
            if average_score >= TRAINING_GOAL: goal_reached = True
            print("Episode {0:>3}: ".format(episode), end = '')
            print("score {0:>3} ".format(math.trunc(score)), end = '')
            print("(exploration rate: %.3f, " % exploration_rate, end = '')
            print("average score: {0:>3}, ".format(round(average_score)), end = '')
            print("transitions: " + str(agent.memory.current_size) + ")")
        else:
            state = state_next
            
    # Decrease exploration rate
    exploration_rate *= EXPLORATION_RATE_DECAY
    exploration_rate = max(EXPLORATION_RATE_MIN, exploration_rate)

print("Time for training: ", end = '')
print_time(time.perf_counter() - start_time)
print("Total steps: ", total_steps)
print("Score (average last episodes):", round(average_score))
print("Score (max):", round(max(agent.scores)))

agent.display_scores_graphically()

agent.save_model()
# Out:
# Episode   1: score -84 (exploration rate: 1.000, average score: -84, transitions: 102)
# Episode   2: score -119 (exploration rate: 0.995, average score: -102, transitions: 188)
# Episode   3: score -189 (exploration rate: 0.990, average score: -131, transitions: 286)
# Episode   4: score -107 (exploration rate: 0.985, average score: -125, transitions: 378)
# Episode   5: score -241 (exploration rate: 0.980, average score: -149, transitions: 493)
# Episode   6: score -64 (exploration rate: 0.975, average score: -134, transitions: 551)
# Episode   7: score -412 (exploration rate: 0.970, average score: -174, transitions: 694)
# Episode   8: score -166 (exploration rate: 0.966, average score: -173, transitions: 766)
# Episode   9: score -606 (exploration rate: 0.961, average score: -221, transitions: 929)
# Episode  10: score -94 (exploration rate: 0.956, average score: -209, transitions: 1020)
# Episode  11: score -116 (exploration rate: 0.951, average score: -200, transitions: 1101)
# Episode  12: score -54 (exploration rate: 0.946, average score: -188, transitions: 1190)
# Episode  13: score -187 (exploration rate: 0.942, average score: -188, transitions: 1290)
# Episode  14: score -181 (exploration rate: 0.937, average score: -188, transitions: 1371)
# Episode  15: score -142 (exploration rate: 0.932, average score: -185, transitions: 1479)
# Episode  16: score -146 (exploration rate: 0.928, average score: -182, transitions: 1565)
# Episode  17: score -371 (exploration rate: 0.923, average score: -193, transitions: 1693)
# Episode  18: score -125 (exploration rate: 0.918, average score: -190, transitions: 1767)
# Episode  19: score -189 (exploration rate: 0.914, average score: -190, transitions: 1875)
# Episode  20: score -130 (exploration rate: 0.909, average score: -187, transitions: 1963)
# Episode  21: score -294 (exploration rate: 0.905, average score: -192, transitions: 2057)
# Episode  22: score -96 (exploration rate: 0.900, average score: -187, transitions: 2183)
# Episode  23: score -110 (exploration rate: 0.896, average score: -184, transitions: 2253)
# Episode  24: score -171 (exploration rate: 0.891, average score: -184, transitions: 2318)
# Episode  25: score -113 (exploration rate: 0.887, average score: -181, transitions: 2404)
# Episode  26: score -89 (exploration rate: 0.882, average score: -177, transitions: 2490)
# Episode  27: score -110 (exploration rate: 0.878, average score: -175, transitions: 2583)
# Episode  28: score -100 (exploration rate: 0.873, average score: -172, transitions: 2656)
# Episode  29: score -120 (exploration rate: 0.869, average score: -170, transitions: 2741)
# Episode  30: score -271 (exploration rate: 0.865, average score: -174, transitions: 2853)
# Episode  31: score -170 (exploration rate: 0.860, average score: -177, transitions: 2947)
# Episode  32: score -20 (exploration rate: 0.856, average score: -173, transitions: 3045)
# Episode  33: score -324 (exploration rate: 0.852, average score: -178, transitions: 3151)
# Episode  34: score -137 (exploration rate: 0.848, average score: -179, transitions: 3246)
# Episode  35: score -223 (exploration rate: 0.843, average score: -178, transitions: 3337)
# Episode  36: score -101 (exploration rate: 0.839, average score: -179, transitions: 3406)
# Episode  37: score -158 (exploration rate: 0.835, average score: -171, transitions: 3520)
# Episode  38: score -114 (exploration rate: 0.831, average score: -169, transitions: 3603)
# Episode  39: score -166 (exploration rate: 0.827, average score: -155, transitions: 3706)
# Episode  40: score -165 (exploration rate: 0.822, average score: -157, transitions: 3791)
# Episode  41: score -167 (exploration rate: 0.818, average score: -159, transitions: 3911)
# Episode  42: score -133 (exploration rate: 0.814, average score: -161, transitions: 4011)
# Episode  43: score -78 (exploration rate: 0.810, average score: -158, transitions: 4153)
# Episode  44: score -187 (exploration rate: 0.806, average score: -158, transitions: 4261)
# Episode  45: score -101 (exploration rate: 0.802, average score: -156, transitions: 4377)
# Episode  46: score  -3 (exploration rate: 0.798, average score: -152, transitions: 4490)
# Episode  47: score -113 (exploration rate: 0.794, average score: -143, transitions: 4619)
# Episode  48: score -101 (exploration rate: 0.790, average score: -142, transitions: 4715)
# Episode  49: score -95 (exploration rate: 0.786, average score: -139, transitions: 4832)
# Episode  50: score -269 (exploration rate: 0.782, average score: -144, transitions: 4961)
# Episode  51: score -241 (exploration rate: 0.778, average score: -142, transitions: 5070)
# Episode  52: score -280 (exploration rate: 0.774, average score: -148, transitions: 5171)
# Episode  53: score -19 (exploration rate: 0.771, average score: -145, transitions: 5255)
# Episode  54: score -86 (exploration rate: 0.767, average score: -142, transitions: 5334)
# Episode  55: score -81 (exploration rate: 0.763, average score: -141, transitions: 5403)
# Episode  56: score -57 (exploration rate: 0.759, average score: -140, transitions: 5547)
# Episode  57: score -89 (exploration rate: 0.755, average score: -139, transitions: 5670)
# Episode  58: score -133 (exploration rate: 0.751, average score: -141, transitions: 5780)
# Episode  59: score -33 (exploration rate: 0.748, average score: -138, transitions: 5922)
# Episode  60: score -105 (exploration rate: 0.744, average score: -132, transitions: 6055)
# Episode  61: score -58 (exploration rate: 0.740, average score: -128, transitions: 6180)
# Episode  62: score -103 (exploration rate: 0.737, average score: -131, transitions: 6261)
# Episode  63: score -217 (exploration rate: 0.733, average score: -128, transitions: 6332)
# Episode  64: score -105 (exploration rate: 0.729, average score: -127, transitions: 6431)
# Episode  65: score -136 (exploration rate: 0.726, average score: -124, transitions: 6533)
# Episode  66: score -32 (exploration rate: 0.722, average score: -121, transitions: 6620)
# Episode  67: score -140 (exploration rate: 0.718, average score: -121, transitions: 6739)
# Episode  68: score -51 (exploration rate: 0.715, average score: -119, transitions: 6808)
# Episode  69: score -34 (exploration rate: 0.711, average score: -114, transitions: 6981)
# Episode  70: score -238 (exploration rate: 0.708, average score: -117, transitions: 7102)
# Episode  71: score -113 (exploration rate: 0.704, average score: -115, transitions: 7189)
# Episode  72: score -102 (exploration rate: 0.701, average score: -114, transitions: 7302)
# Episode  73: score  -9 (exploration rate: 0.697, average score: -112, transitions: 7421)
# Episode  74: score -88 (exploration rate: 0.694, average score: -108, transitions: 7537)
# Episode  75: score -95 (exploration rate: 0.690, average score: -108, transitions: 7623)
# Episode  76: score -16 (exploration rate: 0.687, average score: -109, transitions: 7725)
# Episode  77: score -81 (exploration rate: 0.683, average score: -107, transitions: 7847)
# Episode  78: score -69 (exploration rate: 0.680, average score: -106, transitions: 7935)
# Episode  79: score -58 (exploration rate: 0.676, average score: -105, transitions: 8021)
# Episode  80: score -72 (exploration rate: 0.673, average score: -99, transitions: 8142)
# Episode  81: score -93 (exploration rate: 0.670, average score: -94, transitions: 8244)
# Episode  82: score -58 (exploration rate: 0.666, average score: -86, transitions: 8324)
# Episode  83: score -100 (exploration rate: 0.663, average score: -89, transitions: 8433)
# Episode  84: score -40 (exploration rate: 0.660, average score: -87, transitions: 8645)
# Episode  85: score -39 (exploration rate: 0.656, average score: -86, transitions: 8724)
# Episode  86: score -121 (exploration rate: 0.653, average score: -88, transitions: 8841)
# Episode  87: score -85 (exploration rate: 0.650, average score: -88, transitions: 8972)
# Episode  88: score -46 (exploration rate: 0.647, average score: -85, transitions: 9058)
# Episode  89: score -67 (exploration rate: 0.643, average score: -86, transitions: 9149)
# Episode  90: score -179 (exploration rate: 0.640, average score: -89, transitions: 9249)
# Episode  91: score  -9 (exploration rate: 0.637, average score: -87, transitions: 9392)
# Episode  92: score -33 (exploration rate: 0.634, average score: -85, transitions: 9483)
# Episode  93: score -161 (exploration rate: 0.631, average score: -83, transitions: 9590)
# Episode  94: score -154 (exploration rate: 0.627, average score: -85, transitions: 9702)
# Episode  95: score -110 (exploration rate: 0.624, average score: -84, transitions: 9860)
# Episode  96: score  -8 (exploration rate: 0.621, average score: -83, transitions: 10039)
# Episode  97: score -104 (exploration rate: 0.618, average score: -82, transitions: 10182)
# Episode  98: score -65 (exploration rate: 0.615, average score: -82, transitions: 10308)
# Episode  99: score -138 (exploration rate: 0.612, average score: -86, transitions: 10427)
# Episode 100: score -75 (exploration rate: 0.609, average score: -80, transitions: 10630)
# Episode 101: score -37 (exploration rate: 0.606, average score: -78, transitions: 10706)
# Episode 102: score -77 (exploration rate: 0.603, average score: -77, transitions: 10807)
# Episode 103: score -235 (exploration rate: 0.600, average score: -84, transitions: 10913)
# Episode 104: score -150 (exploration rate: 0.597, average score: -86, transitions: 10980)
# Episode 105: score -98 (exploration rate: 0.594, average score: -86, transitions: 11142)
# Episode 106: score -81 (exploration rate: 0.591, average score: -89, transitions: 11261)
# Episode 107: score -53 (exploration rate: 0.588, average score: -88, transitions: 11379)
# Episode 108: score  15 (exploration rate: 0.585, average score: -85, transitions: 11537)
# Episode 109: score -70 (exploration rate: 0.582, average score: -85, transitions: 11613)
# Episode 110: score -148 (exploration rate: 0.579, average score: -88, transitions: 11718)
# Episode 111: score  34 (exploration rate: 0.576, average score: -84, transitions: 11858)
# Episode 112: score -41 (exploration rate: 0.573, average score: -83, transitions: 12045)
# Episode 113: score -11 (exploration rate: 0.570, average score: -80, transitions: 12121)
# Episode 114: score -21 (exploration rate: 0.568, average score: -79, transitions: 12232)
# Episode 115: score -29 (exploration rate: 0.565, average score: -79, transitions: 12367)
# Episode 116: score -42 (exploration rate: 0.562, average score: -76, transitions: 12463)
# Episode 117: score -74 (exploration rate: 0.559, average score: -76, transitions: 12643)
# Episode 118: score -29 (exploration rate: 0.556, average score: -75, transitions: 12770)
# Episode 119: score -95 (exploration rate: 0.554, average score: -76, transitions: 12946)
# Episode 120: score -37 (exploration rate: 0.551, average score: -72, transitions: 13069)
# Episode 121: score -26 (exploration rate: 0.548, average score: -72, transitions: 13158)
# Episode 122: score   1 (exploration rate: 0.545, average score: -71, transitions: 13316)
# Episode 123: score -20 (exploration rate: 0.543, average score: -66, transitions: 13473)
# Episode 124: score -122 (exploration rate: 0.540, average score: -65, transitions: 13582)
# Episode 125: score -109 (exploration rate: 0.537, average score: -65, transitions: 13680)
# Episode 126: score -30 (exploration rate: 0.534, average score: -66, transitions: 13839)
# Episode 127: score -28 (exploration rate: 0.532, average score: -63, transitions: 14293)
# Episode 128: score   7 (exploration rate: 0.529, average score: -61, transitions: 14424)
# Episode 129: score -14 (exploration rate: 0.526, average score: -57, transitions: 14659)
# Episode 130: score  37 (exploration rate: 0.524, average score: -53, transitions: 14815)
# Episode 131: score -46 (exploration rate: 0.521, average score: -53, transitions: 15017)
# Episode 132: score -93 (exploration rate: 0.519, average score: -54, transitions: 15103)
# Episode 133: score  34 (exploration rate: 0.516, average score: -45, transitions: 15223)
# Episode 134: score  -9 (exploration rate: 0.513, average score: -40, transitions: 15311)
# Episode 135: score -44 (exploration rate: 0.511, average score: -38, transitions: 15404)
# Episode 136: score  24 (exploration rate: 0.508, average score: -35, transitions: 15524)
# Episode 137: score -89 (exploration rate: 0.506, average score: -36, transitions: 15592)
# Episode 138: score -78 (exploration rate: 0.503, average score: -39, transitions: 15706)
# Episode 139: score  30 (exploration rate: 0.501, average score: -36, transitions: 15796)
# Episode 140: score -18 (exploration rate: 0.498, average score: -31, transitions: 15913)
# Episode 141: score -27 (exploration rate: 0.496, average score: -34, transitions: 16060)
# Episode 142: score -68 (exploration rate: 0.493, average score: -34, transitions: 16145)
# Episode 143: score -135 (exploration rate: 0.491, average score: -39, transitions: 16258)
# Episode 144: score -50 (exploration rate: 0.488, average score: -40, transitions: 16343)
# Episode 145: score -62 (exploration rate: 0.486, average score: -41, transitions: 16561)
# Episode 146: score -54 (exploration rate: 0.483, average score: -41, transitions: 16662)
# Episode 147: score -170 (exploration rate: 0.481, average score: -44, transitions: 16917)
# Episode 148: score -167 (exploration rate: 0.479, average score: -49, transitions: 17069)
# Episode 149: score -20 (exploration rate: 0.476, average score: -46, transitions: 17151)
# Episode 150: score -372 (exploration rate: 0.474, average score: -58, transitions: 17521)
# Episode 151: score -154 (exploration rate: 0.471, average score: -62, transitions: 17654)
# Episode 152: score -143 (exploration rate: 0.469, average score: -67, transitions: 18403)
# Episode 153: score -45 (exploration rate: 0.467, average score: -67, transitions: 18510)
# Episode 154: score -15 (exploration rate: 0.464, average score: -64, transitions: 18661)
# Episode 155: score -47 (exploration rate: 0.462, average score: -62, transitions: 18818)
# Episode 156: score -266 (exploration rate: 0.460, average score: -70, transitions: 19013)
# Episode 157: score -38 (exploration rate: 0.458, average score: -70, transitions: 19131)
# Episode 158: score -124 (exploration rate: 0.455, average score: -74, transitions: 19524)
# Episode 159: score -142 (exploration rate: 0.453, average score: -79, transitions: 19695)
# Episode 160: score  30 (exploration rate: 0.451, average score: -79, transitions: 19782)
# Episode 161: score -82 (exploration rate: 0.448, average score: -80, transitions: 20505)
# Episode 162: score  44 (exploration rate: 0.446, average score: -76, transitions: 20612)
# Episode 163: score -335 (exploration rate: 0.444, average score: -88, transitions: 20791)
# Episode 164: score -93 (exploration rate: 0.442, average score: -91, transitions: 20896)
# Episode 165: score -99 (exploration rate: 0.440, average score: -92, transitions: 21022)
# Episode 166: score -43 (exploration rate: 0.437, average score: -95, transitions: 21115)
# Episode 167: score -115 (exploration rate: 0.435, average score: -96, transitions: 21222)
# Episode 168: score -38 (exploration rate: 0.433, average score: -94, transitions: 21306)
# Episode 169: score -102 (exploration rate: 0.431, average score: -99, transitions: 21426)
# Episode 170: score -47 (exploration rate: 0.429, average score: -100, transitions: 21538)
# Episode 171: score -17 (exploration rate: 0.427, average score: -99, transitions: 21626)
# Episode 172: score -168 (exploration rate: 0.424, average score: -103, transitions: 22006)
# Episode 173: score -176 (exploration rate: 0.422, average score: -104, transitions: 22841)
# Episode 174: score -66 (exploration rate: 0.420, average score: -105, transitions: 22950)
# Episode 175: score -61 (exploration rate: 0.418, average score: -105, transitions: 23057)
# Episode 176: score  -4 (exploration rate: 0.416, average score: -103, transitions: 23182)
# Episode 177: score -12 (exploration rate: 0.414, average score: -98, transitions: 24182)
# Episode 178: score -196 (exploration rate: 0.412, average score: -99, transitions: 24475)
# Episode 179: score -183 (exploration rate: 0.410, average score: -104, transitions: 25351)
# Episode 180: score -99 (exploration rate: 0.408, average score: -95, transitions: 26351)
# Episode 181: score -50 (exploration rate: 0.406, average score: -91, transitions: 26423)
# Episode 182: score -100 (exploration rate: 0.404, average score: -90, transitions: 26541)
# Episode 183: score -182 (exploration rate: 0.402, average score: -95, transitions: 26846)
# Episode 184: score -84 (exploration rate: 0.400, average score: -97, transitions: 27846)
# Episode 185: score -10 (exploration rate: 0.398, average score: -96, transitions: 27960)
# Episode 186: score -13 (exploration rate: 0.396, average score: -87, transitions: 28057)
# Episode 187: score -34 (exploration rate: 0.394, average score: -87, transitions: 28198)
# Episode 188: score -44 (exploration rate: 0.392, average score: -84, transitions: 28330)
# Episode 189: score  -9 (exploration rate: 0.390, average score: -80, transitions: 28439)
# Episode 190: score -55 (exploration rate: 0.388, average score: -83, transitions: 29439)
# Episode 191: score -44 (exploration rate: 0.386, average score: -82, transitions: 29550)
# Episode 192: score -44 (exploration rate: 0.384, average score: -85, transitions: 29652)
# Episode 193: score -25 (exploration rate: 0.382, average score: -74, transitions: 29756)
# Episode 194: score -17 (exploration rate: 0.380, average score: -72, transitions: 29891)
# Episode 195: score -17 (exploration rate: 0.378, average score: -69, transitions: 29968)
# Episode 196: score  19 (exploration rate: 0.376, average score: -67, transitions: 30085)
# Episode 197: score -262 (exploration rate: 0.374, average score: -72, transitions: 30569)
# Episode 198: score -185 (exploration rate: 0.373, average score: -77, transitions: 30746)
# Episode 199: score -67 (exploration rate: 0.371, average score: -75, transitions: 30839)
# Episode 200: score   5 (exploration rate: 0.369, average score: -74, transitions: 30967)
# Episode 201: score -308 (exploration rate: 0.367, average score: -83, transitions: 31756)
# Episode 202: score -242 (exploration rate: 0.365, average score: -86, transitions: 32084)
# Episode 203: score  82 (exploration rate: 0.363, average score: -77, transitions: 33084)
# Episode 204: score   5 (exploration rate: 0.361, average score: -75, transitions: 33205)
# Episode 205: score   0 (exploration rate: 0.360, average score: -73, transitions: 33325)
# Episode 206: score  34 (exploration rate: 0.358, average score: -71, transitions: 33456)
# Episode 207: score -34 (exploration rate: 0.356, average score: -72, transitions: 33576)
# Episode 208: score -63 (exploration rate: 0.354, average score: -68, transitions: 34576)
# Episode 209: score -34 (exploration rate: 0.353, average score: -63, transitions: 35576)
# Episode 210: score  -2 (exploration rate: 0.351, average score: -60, transitions: 36576)
# Episode 211: score  -1 (exploration rate: 0.349, average score: -58, transitions: 36683)
# Episode 212: score -73 (exploration rate: 0.347, average score: -57, transitions: 36947)
# Episode 213: score -275 (exploration rate: 0.346, average score: -60, transitions: 37837)
# Episode 214: score -70 (exploration rate: 0.344, average score: -60, transitions: 38837)
# Episode 215: score  55 (exploration rate: 0.342, average score: -58, transitions: 39837)
# Episode 216: score  12 (exploration rate: 0.340, average score: -57, transitions: 39954)
# Episode 217: score -23 (exploration rate: 0.339, average score: -56, transitions: 40954)
# Episode 218: score   1 (exploration rate: 0.337, average score: -55, transitions: 41150)
# Episode 219: score -44 (exploration rate: 0.335, average score: -56, transitions: 41285)
# Episode 220: score  77 (exploration rate: 0.334, average score: -51, transitions: 42285)
# Episode 221: score  74 (exploration rate: 0.332, average score: -48, transitions: 43285)
# Episode 222: score -33 (exploration rate: 0.330, average score: -47, transitions: 43425)
# Episode 223: score 103 (exploration rate: 0.329, average score: -43, transitions: 44425)
# Episode 224: score  99 (exploration rate: 0.327, average score: -39, transitions: 45425)
# Episode 225: score  23 (exploration rate: 0.325, average score: -38, transitions: 45557)
# Episode 226: score   1 (exploration rate: 0.324, average score: -38, transitions: 46557)
# Episode 227: score -28 (exploration rate: 0.322, average score: -30, transitions: 46682)
# Episode 228: score -180 (exploration rate: 0.321, average score: -30, transitions: 46913)
# Episode 229: score -77 (exploration rate: 0.319, average score: -31, transitions: 47913)
# Episode 230: score -19 (exploration rate: 0.317, average score: -31, transitions: 47991)
# Episode 231: score  -7 (exploration rate: 0.316, average score: -21, transitions: 48124)
# Episode 232: score  11 (exploration rate: 0.314, average score: -13, transitions: 48277)
# Episode 233: score -137 (exploration rate: 0.313, average score: -20, transitions: 48404)
# Episode 234: score -44 (exploration rate: 0.311, average score: -22, transitions: 48561)
# Episode 235: score   2 (exploration rate: 0.309, average score: -22, transitions: 49561)
# Episode 236: score  17 (exploration rate: 0.308, average score: -22, transitions: 49661)
# Episode 237: score 104 (exploration rate: 0.306, average score: -18, transitions: 50661)
# Episode 238: score  60 (exploration rate: 0.305, average score: -14, transitions: 51661)
# Episode 239: score -149 (exploration rate: 0.303, average score: -17, transitions: 51882)
# Episode 240: score  38 (exploration rate: 0.302, average score: -16, transitions: 52882)
# Episode 241: score  89 (exploration rate: 0.300, average score: -13, transitions: 53882)
# Episode 242: score   3 (exploration rate: 0.299, average score: -10, transitions: 54882)
# Episode 243: score  -4 (exploration rate: 0.297, average score:  -1, transitions: 54982)
# Episode 244: score -25 (exploration rate: 0.296, average score:   0, transitions: 55464)
# Episode 245: score -73 (exploration rate: 0.294, average score:  -4, transitions: 56464)
# Episode 246: score  14 (exploration rate: 0.293, average score:  -4, transitions: 56564)
# Episode 247: score 119 (exploration rate: 0.291, average score:   1, transitions: 57564)
# Episode 248: score 108 (exploration rate: 0.290, average score:   4, transitions: 58564)
# Episode 249: score  81 (exploration rate: 0.288, average score:   8, transitions: 59564)
# Episode 250: score  44 (exploration rate: 0.287, average score:   7, transitions: 59673)
# Episode 251: score  90 (exploration rate: 0.286, average score:   8, transitions: 60673)
# Episode 252: score  66 (exploration rate: 0.284, average score:  11, transitions: 61673)
# Episode 253: score  -2 (exploration rate: 0.283, average score:   8, transitions: 62673)
# Episode 254: score  90 (exploration rate: 0.281, average score:   7, transitions: 63673)
# Episode 255: score  69 (exploration rate: 0.280, average score:   9, transitions: 64673)
# Episode 256: score -21 (exploration rate: 0.279, average score:   8, transitions: 65673)
# Episode 257: score 103 (exploration rate: 0.277, average score:  12, transitions: 66673)
# Episode 258: score -204 (exploration rate: 0.276, average score:  12, transitions: 67219)
# Episode 259: score  76 (exploration rate: 0.274, average score:  17, transitions: 68219)
# Episode 260: score 277 (exploration rate: 0.273, average score:  27, transitions: 68896)
# Episode 261: score  96 (exploration rate: 0.272, average score:  30, transitions: 69896)
# Episode 262: score  58 (exploration rate: 0.270, average score:  32, transitions: 70896)
# Episode 263: score -189 (exploration rate: 0.269, average score:  30, transitions: 71108)
# Episode 264: score 250 (exploration rate: 0.268, average score:  40, transitions: 71685)
# Episode 265: score  66 (exploration rate: 0.266, average score:  42, transitions: 72685)
# Episode 266: score 110 (exploration rate: 0.265, average score:  45, transitions: 73685)
# Episode 267: score -178 (exploration rate: 0.264, average score:  36, transitions: 74068)
# Episode 268: score  31 (exploration rate: 0.262, average score:  35, transitions: 75068)
# Episode 269: score  11 (exploration rate: 0.261, average score:  40, transitions: 75235)
# Episode 270: score 218 (exploration rate: 0.260, average score:  46, transitions: 75877)
# Episode 271: score   6 (exploration rate: 0.258, average score:  43, transitions: 76877)
# Episode 272: score -153 (exploration rate: 0.257, average score:  38, transitions: 77060)
# Episode 273: score 150 (exploration rate: 0.256, average score:  43, transitions: 78060)
# Episode 274: score -165 (exploration rate: 0.255, average score:  38, transitions: 78176)
# Episode 275: score 126 (exploration rate: 0.253, average score:  45, transitions: 79176)
# Episode 276: score -26 (exploration rate: 0.252, average score:  44, transitions: 79319)
# Episode 277: score -243 (exploration rate: 0.251, average score:  32, transitions: 79818)
# Episode 278: score -153 (exploration rate: 0.249, average score:  23, transitions: 80490)
# Episode 279: score 113 (exploration rate: 0.248, average score:  24, transitions: 81490)
# Episode 280: score -44 (exploration rate: 0.247, average score:  21, transitions: 81588)
# Episode 281: score 104 (exploration rate: 0.246, average score:  22, transitions: 82588)
# Episode 282: score  56 (exploration rate: 0.245, average score:  21, transitions: 83588)
# Episode 283: score -158 (exploration rate: 0.243, average score:  16, transitions: 83825)
# Episode 284: score  10 (exploration rate: 0.242, average score:  13, transitions: 84825)
# Episode 285: score 104 (exploration rate: 0.241, average score:  15, transitions: 85825)
# Episode 286: score 143 (exploration rate: 0.240, average score:  20, transitions: 86825)
# Episode 287: score  99 (exploration rate: 0.238, average score:  20, transitions: 87825)
# Episode 288: score -153 (exploration rate: 0.237, average score:  22, transitions: 88108)
# Episode 289: score 127 (exploration rate: 0.236, average score:  23, transitions: 89108)
# Episode 290: score -15 (exploration rate: 0.235, average score:  14, transitions: 90108)
# Episode 291: score 111 (exploration rate: 0.234, average score:  14, transitions: 91108)
# Episode 292: score -20 (exploration rate: 0.233, average score:  11, transitions: 92108)
# Episode 293: score -217 (exploration rate: 0.231, average score:  10, transitions: 92501)
# Episode 294: score 133 (exploration rate: 0.230, average score:   7, transitions: 93501)
# Episode 295: score  23 (exploration rate: 0.229, average score:   5, transitions: 94501)
# Episode 296: score 145 (exploration rate: 0.228, average score:   6, transitions: 95501)
# Episode 297: score  76 (exploration rate: 0.227, average score:  15, transitions: 96501)
# Episode 298: score 236 (exploration rate: 0.226, average score:  22, transitions: 96989)
# Episode 299: score -272 (exploration rate: 0.225, average score:  12, transitions: 97966)
# Episode 300: score 225 (exploration rate: 0.223, average score:  12, transitions: 98211)
# Episode 301: score 169 (exploration rate: 0.222, average score:  18, transitions: 99211)
# Episode 302: score 169 (exploration rate: 0.221, average score:  29, transitions: 100000)
# Episode 303: score 113 (exploration rate: 0.220, average score:  27, transitions: 100000)
# Episode 304: score 238 (exploration rate: 0.219, average score:  41, transitions: 100000)
# Episode 305: score 102 (exploration rate: 0.218, average score:  40, transitions: 100000)
# Episode 306: score 273 (exploration rate: 0.217, average score:  50, transitions: 100000)
# Episode 307: score 233 (exploration rate: 0.216, average score:  66, transitions: 100000)
# Episode 308: score 115 (exploration rate: 0.215, average score:  75, transitions: 100000)
# Episode 309: score -155 (exploration rate: 0.214, average score:  66, transitions: 100000)
# Episode 310: score  71 (exploration rate: 0.212, average score:  70, transitions: 100000)
# Episode 311: score  97 (exploration rate: 0.211, average score:  70, transitions: 100000)
# Episode 312: score 248 (exploration rate: 0.210, average score:  76, transitions: 100000)
# Episode 313: score -28 (exploration rate: 0.209, average score:  80, transitions: 100000)
# Episode 314: score  41 (exploration rate: 0.208, average score:  81, transitions: 100000)
# Episode 315: score 231 (exploration rate: 0.207, average score:  86, transitions: 100000)
# Episode 316: score 258 (exploration rate: 0.206, average score:  89, transitions: 100000)
# Episode 317: score 124 (exploration rate: 0.205, average score:  90, transitions: 100000)
# Episode 318: score  -1 (exploration rate: 0.204, average score:  95, transitions: 100000)
# Episode 319: score 224 (exploration rate: 0.203, average score:  99, transitions: 100000)
# Episode 320: score 108 (exploration rate: 0.202, average score: 103, transitions: 100000)
# Episode 321: score 278 (exploration rate: 0.201, average score: 108, transitions: 100000)
# Episode 322: score 128 (exploration rate: 0.200, average score: 113, transitions: 100000)
# Episode 323: score 117 (exploration rate: 0.199, average score: 124, transitions: 100000)
# Episode 324: score  98 (exploration rate: 0.198, average score: 123, transitions: 100000)
# Episode 325: score  98 (exploration rate: 0.197, average score: 126, transitions: 100000)
# Episode 326: score 241 (exploration rate: 0.196, average score: 129, transitions: 100000)
# Episode 327: score 143 (exploration rate: 0.195, average score: 131, transitions: 100000)
# Episode 328: score  75 (exploration rate: 0.194, average score: 126, transitions: 100000)
# Episode 329: score   0 (exploration rate: 0.193, average score: 135, transitions: 100000)
# Episode 330: score 256 (exploration rate: 0.192, average score: 136, transitions: 100000)
# Episode 331: score -195 (exploration rate: 0.191, average score: 124, transitions: 100000)
# Episode 332: score 112 (exploration rate: 0.190, average score: 122, transitions: 100000)
# Episode 333: score 200 (exploration rate: 0.189, average score: 125, transitions: 100000)
# Episode 334: score 141 (exploration rate: 0.188, average score: 121, transitions: 100000)
# Episode 335: score -223 (exploration rate: 0.187, average score: 111, transitions: 100000)
# Episode 336: score 173 (exploration rate: 0.187, average score: 107, transitions: 100000)
# Episode 337: score 101 (exploration rate: 0.186, average score: 103, transitions: 100000)
# Episode 338: score 134 (exploration rate: 0.185, average score: 103, transitions: 100000)
# Episode 339: score -398 (exploration rate: 0.184, average score:  95, transitions: 100000)
# Episode 340: score 254 (exploration rate: 0.183, average score: 101, transitions: 100000)
# Episode 341: score 111 (exploration rate: 0.182, average score: 102, transitions: 100000)
# Episode 342: score 132 (exploration rate: 0.181, average score:  98, transitions: 100000)
# Episode 343: score 219 (exploration rate: 0.180, average score: 106, transitions: 100000)
# Episode 344: score 151 (exploration rate: 0.179, average score: 110, transitions: 100000)
# Episode 345: score 181 (exploration rate: 0.178, average score: 108, transitions: 100000)
# Episode 346: score 237 (exploration rate: 0.177, average score: 108, transitions: 100000)
# Episode 347: score 241 (exploration rate: 0.177, average score: 112, transitions: 100000)
# Episode 348: score 142 (exploration rate: 0.176, average score: 116, transitions: 100000)
# Episode 349: score 290 (exploration rate: 0.175, average score: 118, transitions: 100000)
# Episode 350: score 217 (exploration rate: 0.174, average score: 122, transitions: 100000)
# Episode 351: score 231 (exploration rate: 0.173, average score: 121, transitions: 100000)
# Episode 352: score 264 (exploration rate: 0.172, average score: 125, transitions: 100000)
# Episode 353: score 187 (exploration rate: 0.171, average score: 127, transitions: 100000)
# Episode 354: score 117 (exploration rate: 0.170, average score: 128, transitions: 100000)
# Episode 355: score 200 (exploration rate: 0.170, average score: 131, transitions: 100000)
# Episode 356: score -148 (exploration rate: 0.169, average score: 118, transitions: 100000)
# Episode 357: score  60 (exploration rate: 0.168, average score: 116, transitions: 100000)
# Episode 358: score 247 (exploration rate: 0.167, average score: 121, transitions: 100000)
# Episode 359: score  14 (exploration rate: 0.166, average score: 122, transitions: 100000)
# Episode 360: score -86 (exploration rate: 0.165, average score: 111, transitions: 100000)
# Episode 361: score 111 (exploration rate: 0.165, average score: 121, transitions: 100000)
# Episode 362: score 172 (exploration rate: 0.164, average score: 123, transitions: 100000)
# Episode 363: score 208 (exploration rate: 0.163, average score: 123, transitions: 100000)
# Episode 364: score -138 (exploration rate: 0.162, average score: 114, transitions: 100000)
# Episode 365: score   1 (exploration rate: 0.161, average score: 121, transitions: 100000)
# Episode 366: score 235 (exploration rate: 0.160, average score: 123, transitions: 100000)
# Episode 367: score 257 (exploration rate: 0.160, average score: 128, transitions: 100000)
# Episode 368: score 209 (exploration rate: 0.159, average score: 131, transitions: 100000)
# Episode 369: score 309 (exploration rate: 0.158, average score: 155, transitions: 100000)
# Episode 370: score 247 (exploration rate: 0.157, average score: 154, transitions: 100000)
# Episode 371: score 275 (exploration rate: 0.157, average score: 160, transitions: 100000)
# Episode 372: score 210 (exploration rate: 0.156, average score: 162, transitions: 100000)
# Episode 373: score 268 (exploration rate: 0.155, average score: 164, transitions: 100000)
# Episode 374: score 177 (exploration rate: 0.154, average score: 165, transitions: 100000)
# Episode 375: score  72 (exploration rate: 0.153, average score: 161, transitions: 100000)
# Episode 376: score   0 (exploration rate: 0.153, average score: 153, transitions: 100000)
# Episode 377: score -165 (exploration rate: 0.152, average score: 140, transitions: 100000)
# Episode 378: score -24 (exploration rate: 0.151, average score: 134, transitions: 100000)
# Episode 379: score -156 (exploration rate: 0.150, average score: 119, transitions: 100000)
# Episode 380: score 252 (exploration rate: 0.150, average score: 121, transitions: 100000)
# Episode 381: score -218 (exploration rate: 0.149, average score: 106, transitions: 100000)
# Episode 382: score 263 (exploration rate: 0.148, average score: 105, transitions: 100000)
# Episode 383: score  89 (exploration rate: 0.147, average score: 102, transitions: 100000)
# Episode 384: score 214 (exploration rate: 0.147, average score: 105, transitions: 100000)
# Episode 385: score -77 (exploration rate: 0.146, average score:  96, transitions: 100000)
# Episode 386: score 306 (exploration rate: 0.145, average score: 111, transitions: 100000)
# Episode 387: score -43 (exploration rate: 0.144, average score: 108, transitions: 100000)
# Episode 388: score 270 (exploration rate: 0.144, average score: 109, transitions: 100000)
# Episode 389: score 202 (exploration rate: 0.143, average score: 115, transitions: 100000)
# Episode 390: score 211 (exploration rate: 0.142, average score: 125, transitions: 100000)
# Episode 391: score 135 (exploration rate: 0.142, average score: 126, transitions: 100000)
# Episode 392: score 249 (exploration rate: 0.141, average score: 128, transitions: 100000)
# Episode 393: score 126 (exploration rate: 0.140, average score: 125, transitions: 100000)
# Episode 394: score 234 (exploration rate: 0.139, average score: 138, transitions: 100000)
# Episode 395: score 120 (exploration rate: 0.139, average score: 142, transitions: 100000)
# Episode 396: score 162 (exploration rate: 0.138, average score: 139, transitions: 100000)
# Episode 397: score -170 (exploration rate: 0.137, average score: 125, transitions: 100000)
# Episode 398: score 248 (exploration rate: 0.137, average score: 126, transitions: 100000)
# Episode 399: score 287 (exploration rate: 0.136, average score: 126, transitions: 100000)
# Episode 400: score 233 (exploration rate: 0.135, average score: 125, transitions: 100000)
# Episode 401: score 288 (exploration rate: 0.135, average score: 126, transitions: 100000)
# Episode 402: score 266 (exploration rate: 0.134, average score: 127, transitions: 100000)
# Episode 403: score 251 (exploration rate: 0.133, average score: 127, transitions: 100000)
# Episode 404: score 229 (exploration rate: 0.133, average score: 129, transitions: 100000)
# Episode 405: score 255 (exploration rate: 0.132, average score: 135, transitions: 100000)
# Episode 406: score  72 (exploration rate: 0.131, average score: 137, transitions: 100000)
# Episode 407: score 207 (exploration rate: 0.131, average score: 150, transitions: 100000)
# Episode 408: score 279 (exploration rate: 0.130, average score: 160, transitions: 100000)
# Episode 409: score 223 (exploration rate: 0.129, average score: 172, transitions: 100000)
# Episode 410: score 149 (exploration rate: 0.129, average score: 169, transitions: 100000)
# Episode 411: score 295 (exploration rate: 0.128, average score: 186, transitions: 100000)
# Episode 412: score 290 (exploration rate: 0.127, average score: 187, transitions: 100000)
# Episode 413: score 271 (exploration rate: 0.127, average score: 193, transitions: 100000)
# Episode 414: score 283 (exploration rate: 0.126, average score: 195, transitions: 100000)
# Episode 415: score 234 (exploration rate: 0.126, average score: 206, transitions: 100000)
# Time for training: 10 min 18 seconds
# Total steps:  174802
# Score (average last episodes): 206
# Score (max): 309

# %% [markdown]
# ## Testing program

# %%
episode = 0
score_list = []
while (episode < EPISODES_TO_EVALUATE_MODEL_PERFORMANCE):
    episode += 1
    score = 0
    state, info = environment.reset()
    end_episode = False
    while not(end_episode):
        # Select an action for the current state
        action = agent.select_greedy_policy(state)

        # Execute the action in the environment
        state_next, reward, terminal_state, truncated, info = environment.step(action)
        
        score += reward
        state = state_next
        end_episode = terminal_state or truncated
        
    score_list.append(score)
    print("Episode {0:>3}: ".format(episode), end = '')
    print("score {0:>3} \n".format(round(score)), end = '')
                
print("Score (average):", round(np.mean(score_list)))
# Out:
# Episode   1: score 264
# Episode   2: score 276
# Episode   3: score 277
# Episode   4: score 274
# Episode   5: score 276
# Episode   6: score 285
# Episode   7: score 276
# Episode   8: score 221
# Episode   9: score 164
# Episode  10: score 253
# Episode  11: score 153
# Episode  12: score 110
# Episode  13: score 291
# Episode  14: score 213
# Episode  15: score 201
# Episode  16: score 253
# Episode  17: score 281
# Episode  18: score 291
# Episode  19: score  67
# Episode  20: score 103
# Episode  21: score 272
# Episode  22: score 292
# Episode  23: score 115
# Episode  24: score 252
# Episode  25: score 254
# Episode  26: score 277
# Episode  27: score 271
# Episode  28: score 242
# Episode  29: score 275
# Episode  30: score 243
# Score (average): 234

# %% [markdown]
# # Memoria
#
# ## Primera prueba
#
# Se sustituyó el entorno original `CartPole-v1` por `LunarLander-v3`. Además, para realizar una primera prueba rápida, se modificaron algunos hiperparámetros:
#
# ```python
# EPISODES_TO_CHECK_TRAINING_GOAL = 30
# TRAINING_GOAL = 200
# MAX_EPISODES_FOR_TRAINING = 50
# ```
#
# No se modificó la arquitectura de la red ni el resto de la lógica principal del algoritmo.
#
# ### Resultados
#
# - **Pasos totales de entrenamiento:** 5728
# - **Puntuación media final en entrenamiento:** -102
# - **Puntuación máxima en entrenamiento:** -9
# - **Puntuación media en test (30 episodios):** -214
#
# ### Conclusión
#
# El cambio de entorno por sí solo no es suficiente para obtener un comportamiento aceptable en `LunarLander-v3`. Aunque el código ejecuta correctamente, el rendimiento sigue siendo muy bajo, por lo que será necesario modificar la arquitectura o los hiperparámetros en los siguientes experimentos.
#
# ## Segunda prueba
#
# Se introdujo una **target network** para estabilizar el aprendizaje del algoritmo DQN, de forma que los valores objetivo no se calcularan con la misma red que se actualiza en cada iteración. Además, se aumentó la capacidad de la red neuronal a dos capas ocultas de 128 neuronas con activación ReLU, y se incrementó el número máximo de episodios de entrenamiento a 300. También se corrigió el almacenamiento de transiciones finales usando `terminated or truncated`.
#
# ### Justificación
#
# Este cambio se realizó porque en Deep Q-Learning se recomienda utilizar una red objetivo separada para reducir la inestabilidad del entrenamiento. Además, dado que `LunarLander-v3` es un entorno más complejo que `CartPole-v1`, se consideró razonable aumentar la complejidad del modelo y entrenar durante más episodios.
#
# ### Resultados
#
# - **Pasos totales de entrenamiento:** 90503
# - **Puntuación media final en entrenamiento:** -2
# - **Puntuación máxima en entrenamiento:** 269
# - **Puntuación media en test (30 episodios):** 45
#
# ### Conclusión
#
# Este cambio produjo una mejora clara respecto a la primera prueba, ya que el agente empezó a obtener episodios con puntuaciones positivas e incluso alcanzó una puntuación máxima de 269 durante el entrenamiento. Sin embargo, la puntuación media en test sigue siendo insuficiente.
#
# ## Tercer prueba
#
# Se mantuvo la configuración de la segunda prueba, incluyendo la **target network**, la red neuronal con dos capas ocultas de 128 neuronas y la corrección del almacenamiento de transiciones finales. En esta prueba únicamente se aumentó el número máximo de episodios de entrenamiento de 300 a 600.
#
# ### Justificación
#
# Este cambio se realizó para comprobar si la política aprendida en la segunda prueba podía seguir mejorando simplemente aumentando el tiempo de entrenamiento. Una de las estrategias para mejorar el rendimiento de una red es aumentar el número de iteraciones cuando el ajuste todavía es insuficiente.
#
# ### Resultados
#
# - **Pasos totales de entrenamiento:** 198426
# - **Puntuación media final en entrenamiento:** 202
# - **Puntuación máxima en entrenamiento:** 306
# - **Puntuación media en test (30 episodios):** 187
#
# ### Conclusión
#
# Este cambio mejoró claramente los resultados de la segunda prueba. La puntuación media en test pasó de 45 a 187, y durante el entrenamiento se alcanzó una media final de 202 y una puntuación máxima de 306. Por tanto, aumentar el número de episodios de entrenamiento fue una decisión acertada, aunque todavía no se alcanza el objetivo de 200 puntos de media en test.
#
# ## Cuarta prueba
#
# Se mantuvo la configuración de la tercera prueba y únicamente se redujo la tasa de aprendizaje, cambiando:
#
# ```python
# LEARNING_RATE = 0.0005
# ```
#
# ### Justificación
#
# Este cambio se realizó para comprobar si una tasa de aprendizaje más baja permite estabilizar mejor el proceso de entrenamiento y consolidar la política aprendida. Dado que en la tercera prueba el agente ya consiguió una puntuación media de 187 en test, muy próxima al objetivo, esta modificación busca un ajuste fino que permita mejorar la generalización sin alterar el resto de la configuración.
#
# ### Resultados
#
# - **Pasos totales de entrenamiento:** 164319
# - **Puntuación media final en entrenamiento:** 201
# - **Puntuación máxima en entrenamiento:** 288
# - **Puntuación media en test (30 episodios):** 232
#
# ### Conclusion
#
# Este cambio mejoró claramente los resultados de la tercera prueba. La puntuación media en test pasó de 187 a 232, superando el objetivo de 200 puntos de media exigido por la práctica. Además, durante el entrenamiento se alcanzó una media final de 201 y una puntuación máxima de 288. Por tanto, reducir la tasa de aprendizaje fue una decisión acertada.
#
# ## Quinta prueba
#
# Se mantuvo la configuración de la cuarta prueba, incluyendo la red neuronal con dos capas ocultas de 128 neuronas, la tasa de aprendizaje reducida (`LEARNING_RATE = 0.0005`) y el entrenamiento con parada anticipada al alcanzar el objetivo. En esta prueba únicamente se modificó la frecuencia de actualización de la **target network**, cambiando:
#
# ```python
# TARGET_UPDATE_FREQUENCY = 500
# ```
#
# ### Justificación
#
# Este cambio se realizó para comprobar si una actualización menos frecuente de la target network permite estabilizar mejor el aprendizaje. En Deep Q-Learning, la red objetivo se utiliza para reducir la variabilidad del target durante el entrenamiento, por lo que espaciar sus actualizaciones podría ayudar a consolidar una política más estable sin modificar el resto de la configuración.
#
#
# ### Resultados
#
# - **Pasos totales de entrenamiento:** 174802
# - **Puntuación media final en entrenamiento:** 206
# - **Puntuación máxima en entrenamiento:** 309
# - **Puntuación media en test (30 episodios):** 234
#
# ### Conclusion
#
# Este cambio mantuvo un rendimiento alto y permitió seguir superando el objetivo de 200 puntos de media en test. Sin embargo, la mejora respecto a la cuarta prueba fue mínima, ya que la puntuación media en test solo pasó de 232 a 234, a costa de un mayor número de pasos de entrenamiento. Por tanto, aunque la configuración sigue siendo válida, no aporta una mejora relevante frente a la cuarta prueba.
#
# Estas pruebas permitieron identificar una versión final del agente DQN para `LunarLander-v3`, mostrando además, a través de las distintas pruebas intermedias, qué modificaciones resultaron realmente útiles y cuáles no aportaron mejoras significativas.

# %%
import tensorflow as tf

model = tf.keras.models.load_model("my_model.keras")
model.summary()

for layer in model.layers:
    print(layer.name)
    print(layer.get_weights())
# Out:
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_42 (Dense)                │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_44 (Dense)                │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 54,542 (213.06 KB)
#  Trainable params: 18,180 (71.02 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 36,362 (142.04 KB)
# dense_42
# [array([[ 0.21249957, -0.5546107 ,  0.06290743, ...,  0.6431155 ,
#         -0.54312295, -1.2967302 ],
#        [ 0.13539118, -1.1575006 , -0.16923678, ...,  1.8479041 ,
#         -0.92815846, -1.7396216 ],
#        [ 0.05955703, -1.2756208 ,  0.7393098 , ..., -0.67289954,
#         -0.49603367, -0.8318513 ],
#        ...,
#        [-0.52409   , -0.7282408 , -1.118114  , ...,  0.3794362 ,
#          0.74870807,  0.08246832],
#        [ 0.04643398, -1.5955274 ,  0.19224674, ...,  0.6895936 ,
#          0.8843625 ,  0.43406633],
#        [ 0.68532795, -1.1284239 , -0.17184676, ..., -0.4334445 ,
#         -0.2046174 ,  0.16736907]], dtype=float32), array([ 2.6702297e-01,  3.7732652e-01,  1.2156863e+00, -1.1080414e-01,
#         4.2805770e-01, -7.8151867e-02, -1.0792700e-01, -8.0471568e-02,
#         4.9019143e-01,  2.7197788e-02,  1.6965631e-01, -8.6044766e-02,
#         7.0981449e-01,  4.1349638e-01,  3.3768883e-01, -1.4352128e-01,
#         3.5137512e-02,  6.6850621e-01, -4.7815898e-01,  6.8317711e-01,
#         1.4863211e-02,  4.6221814e-01, -8.1035584e-01,  1.9826119e-01,
#         1.5979964e+00,  4.3077314e-01, -3.5441869e-01, -1.7189804e-01,
#         1.2151828e-01, -2.5280437e-01,  2.6411745e-01, -5.8724009e-02,
#        -3.9423341e-01, -1.9809824e-01,  5.9328873e-02, -3.8273301e-02,
#         5.1301080e-01,  3.9942485e-01, -3.1281471e-01, -1.5722983e-01,
#        -2.1032336e-01,  3.1521785e-01, -3.0105937e-01,  1.1022229e+00,
#        -4.8856583e-01,  6.2152302e-01,  4.7834608e-01,  3.0927794e-02,
#         4.8704919e-01, -1.9615361e-02, -3.5174024e-01,  1.6816835e-01,
#        -3.3576196e-01,  1.1569624e-01, -1.1271867e-01, -3.5868356e-01,
#         9.3541795e-01, -2.2930939e-01,  1.2093718e-01,  1.6752900e-01,
#        -7.6495588e-02,  3.8617320e-02,  2.7415040e-01,  4.5881239e-01,
#         2.4534966e-01,  3.6582437e-01, -6.5391999e-01,  3.4631756e-01,
#         4.9138373e-01,  2.4986562e-01,  2.0723496e-01,  2.6474506e-01,
#        -2.9674500e-02,  5.4264086e-01,  6.1728667e-02,  1.2419616e-01,
#        -3.1366357e-01,  3.6280760e-01, -6.3226277e-01,  3.0009070e-01,
#        -1.5341690e-01, -3.3571067e-01,  2.5948858e-01,  7.1059948e-01,
#        -3.7236708e-01, -9.2366017e-02, -9.0777516e-02,  6.2832218e-01,
#         6.8127292e-01,  8.8665926e-01,  5.2649510e-01, -7.3988485e-01,
#         1.9214474e-01, -4.5567921e-01, -3.6669183e-01,  7.1957880e-01,
#         6.8030745e-01,  1.0144207e+00,  2.0755963e-01, -2.8996265e-01,
#        -2.0182902e-01,  2.9198903e-01, -3.7552185e-05,  4.8706612e-01,
#         7.6653713e-01,  8.0665600e-01, -3.5211155e-01,  1.9289304e-01,
#        -1.3322292e-01,  1.5553214e-01,  9.4599205e-01, -2.9479569e-01,
#         2.2339733e-01, -2.7255839e-01, -9.0911680e-01, -3.4713545e-01,
#        -3.8939606e-02,  1.0573664e+00, -5.0244160e-02, -8.4449492e-02,
#        -1.3633150e-01, -4.6814535e-02,  5.0179720e-01,  6.3537765e-01,
#         6.3656414e-01,  5.6676102e-01, -2.6503962e-01, -5.4620225e-03],
#       dtype=float32)]
# dense_43
# [array([[ 5.3464413e-02, -1.2558700e-01, -5.3602189e-01, ...,
#         -1.0099108e-01, -7.1120359e-02,  6.2631816e-01],
#        [-8.7999463e-01, -1.3553847e-01,  4.2474756e-01, ...,
#          1.7479198e-01,  5.8805622e-02, -2.8938505e-01],
#        [ 6.0108484e-04,  1.0253046e-01,  1.9440095e-01, ...,
#         -2.0285982e-01, -6.1097324e-01, -1.4932803e+00],
#        ...,
#        [-6.2851864e-01, -3.0201995e-01, -9.8876530e-01, ...,
#          8.4192127e-02, -6.3436174e-01,  3.9750224e-01],
#        [-7.2048098e-02,  3.2263896e-01,  1.1595620e-01, ...,
#          5.5553079e-01,  1.1448126e-01,  2.4326146e-01],
#        [-4.7712080e-02,  3.3392245e-01, -1.0960549e-01, ...,
#         -3.4566201e-02,  4.6738076e-01, -2.6711586e-01]], dtype=float32), array([ 0.10437109, -0.2881593 ,  0.07621126,  0.300781  ,  0.7205141 ,
#         0.2827428 , -0.11766613, -0.28535134, -0.16845115,  0.509722  ,
#        -0.22215635, -0.23045917, -0.0596344 , -0.12502483, -0.19443959,
#         0.2868175 , -0.1852871 ,  0.21559751,  0.16500683, -0.29931325,
#        -0.21238711, -0.03148941, -0.25687772,  0.60885847, -0.0506277 ,
#         0.13760857, -0.24728794,  0.37575197, -0.03747718, -0.08499112,
#        -0.14107478, -0.04093891,  0.13777398,  0.09978948,  0.06403166,
#         0.26088914, -0.06198613, -0.23421906, -0.07332298, -0.12169847,
#         0.4433444 , -0.03519563,  0.12946877,  0.11991569, -0.19292866,
#        -0.09096185,  0.32032108,  0.22641562, -0.16243072, -0.0125695 ,
#         0.16606705, -0.48450965,  0.07757746, -0.08689885, -0.02679344,
#        -0.14849924, -0.03755085,  0.34903657,  0.11083085, -0.1722727 ,
#        -0.27656397,  0.6050369 , -0.03913429, -0.10911242, -0.11493571,
#        -0.17677191,  0.38492504, -0.09536842, -0.05345203,  0.22476175,
#        -0.08460521,  0.36533743,  0.12155908,  0.4284495 ,  0.07615887,
#        -0.31724387, -0.14904778, -0.2356664 ,  0.10439882,  0.65368164,
#        -0.33660322, -0.03221673,  0.14896153, -0.49015236, -0.3296354 ,
#         0.2689505 ,  0.0494488 , -0.17418568, -0.24279413, -0.4115761 ,
#         0.15370277,  0.0732157 ,  0.16863889,  0.41595516, -0.01076582,
#        -0.04758826, -0.06529243, -0.17272517,  0.1373721 ,  0.5355337 ,
#         0.3630976 ,  0.3210895 , -0.0580939 , -0.03927242, -0.07923212,
#         0.11232548, -0.09508652,  0.3946028 ,  0.84911615,  0.38781986,
#         0.0718421 ,  0.3038005 ,  0.0724965 , -0.03654766, -0.17128052,
#         0.07371015, -0.34075624,  0.02717007, -0.21621555, -0.07775212,
#        -0.0602031 , -0.20309304,  0.03519899,  0.0733064 ,  0.08786121,
#        -0.16409206, -0.11928076,  0.14632161], dtype=float32)]
# dense_44
# [array([[ 0.7996208 ,  0.05888814, -0.7674181 , -0.50057036],
#        [-0.36935818, -0.69410986, -1.1632183 , -0.66708153],
#        [ 0.44420066,  0.97769594,  0.8299855 ,  0.8262645 ],
#        [-0.93542135, -1.2177184 , -0.9884373 , -1.2029932 ],
#        [ 2.1973333 ,  2.0443914 ,  2.0403488 ,  2.3638139 ],
#        [-0.7522714 , -0.14049459, -0.83783966, -0.21414837],
#        [-0.02544663, -1.0412772 ,  0.14775664,  1.1395762 ],
#        [-0.9100512 , -0.8952813 , -1.0013118 , -0.7303682 ],
#        [-0.60944617, -0.95264566, -0.7791117 , -0.32299286],
#        [ 1.0712109 ,  0.8665548 ,  1.3885008 ,  1.2014911 ],
#        [-0.13640463, -0.8845909 , -0.47171393, -0.7623059 ],
#        [-2.019093  , -1.8307939 , -1.9071251 , -1.9344295 ],
#        [-0.3018877 ,  0.1818401 ,  1.0535583 ,  1.7477484 ],
#        [ 0.91680306,  0.22660643,  0.9469236 ,  0.88663834],
#        [-0.8350503 , -0.9937515 , -0.5321689 , -0.9264123 ],
#        [-1.0082828 , -0.5947286 , -0.81407684, -0.64869016],
#        [ 0.57741755,  0.0992363 ,  0.34446704,  0.4963025 ],
#        [ 1.0981772 ,  1.050729  ,  1.0338718 ,  0.94481725],
#        [-1.6932552 , -0.8527859 , -1.1827337 , -0.09156235],
#        [-0.37366742, -0.59653884, -0.82510585, -0.08723188],
#        [-0.53138167, -0.62333804, -0.5965795 , -0.79036057],
#        [ 0.06100184, -0.03427114,  0.00517656, -0.14808309],
#        [-1.4654369 , -1.109702  , -2.204645  , -1.7289479 ],
#        [ 0.82730764,  0.4535219 ,  1.4031783 ,  0.7670042 ],
#        [ 0.06728535, -0.5112677 ,  0.11898848, -1.0616131 ],
#        [-0.00871991, -0.46738794,  0.8638752 , -0.8716612 ],
#        [-0.53960663, -0.44909278, -1.3904451 , -0.68178076],
#        [ 1.2533009 ,  1.1814125 ,  0.97576797,  0.85930276],
#        [ 0.14539056,  0.02510457, -0.00746951,  0.19273311],
#        [-0.6848642 , -0.8212179 , -1.0928077 , -0.4085823 ],
#        [-0.9241457 , -0.92070055, -0.7431979 , -0.59957194],
#        [ 0.24628711,  0.20452315, -0.8090277 ,  0.5055467 ],
#        [-0.9489501 , -0.45910838, -0.7761595 , -0.6479843 ],
#        [-0.07459958,  1.1374215 ,  0.689207  ,  1.5131849 ],
#        [-1.0509578 , -0.44791386, -0.96155363, -0.38396072],
#        [-0.12972789, -0.7162166 ,  0.24969876, -0.89013124],
#        [ 0.73458135,  0.6176968 ,  0.8346515 ,  0.9114335 ],
#        [-0.36191854, -1.1859426 , -1.2548218 , -1.0226811 ],
#        [-0.04394813,  0.11218501,  0.02077637, -0.09576114],
#        [-0.9176307 , -0.7178822 , -0.58708894,  0.05806348],
#        [ 2.4321108 ,  2.5235498 ,  2.2938843 ,  2.1980042 ],
#        [ 0.07247908, -0.1057433 , -0.00633096,  0.07995192],
#        [ 0.28133246,  0.15508181, -0.6180441 ,  0.59537977],
#        [-0.6904831 , -0.5020234 , -0.46947113, -0.56982267],
#        [-0.17698976, -0.9127233 , -0.8608898 , -0.23519136],
#        [-0.72146326, -0.66891223, -0.47030985, -0.8736597 ],
#        [ 0.15415454, -0.0662095 ,  0.33270365,  0.05975361],
#        [ 1.6376525 ,  1.6292125 ,  1.5163394 ,  1.2913094 ],
#        [-0.5224124 , -0.6474289 , -0.60257417, -0.8969332 ],
#        [-0.06413877,  0.07603856, -0.09528517,  0.15411231],
#        [ 0.39750323,  1.2845262 ,  1.2682923 ,  0.7690373 ],
#        [-1.1354198 , -0.5643048 , -0.9565913 , -1.1889735 ],
#        [-0.940121  , -0.8231523 , -0.83647984, -0.7583715 ],
#        [-0.9423833 , -0.68897253, -0.6183337 , -0.91222423],
#        [ 0.00480034, -0.682216  , -1.2603257 , -0.8333263 ],
#        [-0.4228637 , -0.5973557 , -0.80824304, -0.3540653 ],
#        [ 0.14996155, -0.00862873, -0.17052191,  0.08590233],
#        [ 0.13956739,  0.06858578,  0.57559353,  0.38723275],
#        [-0.75226486, -0.40557712, -0.66098255, -0.6137582 ],
#        [-1.2543626 , -1.8639599 , -0.71393657,  0.11238813],
#        [ 0.90376097, -0.00532165,  0.34976575,  0.42706034],
#        [ 1.2194471 ,  0.41723597,  0.9400141 ,  0.93658745],
#        [ 0.18407859,  0.10287999,  0.40049478,  0.7220854 ],
#        [ 1.6762373 ,  2.0568972 ,  2.246822  ,  2.0686834 ],
#        [ 0.76848376,  0.3105484 ,  0.90024674,  0.65481025],
#        [-0.39121813,  0.15721117, -0.96874684, -0.44469377],
#        [ 0.6737266 ,  0.6017862 ,  0.86873263,  0.7710472 ],
#        [-0.6124186 , -0.91370744, -1.0617082 , -0.67118454],
#        [ 0.20282534,  0.70209926, -0.67390496,  1.3253924 ],
#        [-0.7979518 , -1.2441732 , -2.5615344 , -1.1301606 ],
#        [-0.9696437 , -0.89546895, -1.5516123 , -0.41268846],
#        [-1.51471   , -1.007975  , -1.3536366 , -0.9553956 ],
#        [ 0.19763093,  0.8309289 ,  1.2319292 , -0.42043003],
#        [-1.3108128 , -0.7154576 , -0.16436435, -1.461345  ],
#        [-0.72232705, -1.1453741 , -0.29074752, -0.9711365 ],
#        [-0.235658  , -0.5429551 , -0.5439273 , -0.9284289 ],
#        [-0.47368553, -0.6398042 , -0.5493929 , -0.6759141 ],
#        [-0.07131443,  0.30514848, -0.68633974, -0.44443303],
#        [-1.0278398 , -0.9473346 , -0.8491928 , -1.1748599 ],
#        [ 0.9650848 ,  1.4462293 ,  0.7044595 ,  1.2391794 ],
#        [-1.2023281 , -1.0592086 , -0.980038  , -0.83790815],
#        [-0.14416775, -0.03536045,  0.09218957,  0.18825096],
#        [ 1.3325425 ,  1.3065326 ,  1.1798213 ,  1.7479618 ],
#        [ 1.5512595 ,  1.8529445 ,  1.348634  ,  1.3765959 ],
#        [-0.34084234, -0.30517578, -0.96366924, -0.95689577],
#        [ 0.33623055,  0.7630609 ,  0.7676806 ,  0.38644466],
#        [ 0.29364046,  0.733287  , -0.03740498, -0.07651933],
#        [-0.22680981, -0.46334738, -0.20192468, -0.5884566 ],
#        [-0.6537928 , -0.8963731 , -0.8778132 , -0.6627496 ],
#        [-1.1150644 , -0.08076503,  0.3958836 , -1.1426878 ],
#        [-0.7403807 , -0.6560497 , -0.7242838 , -0.90207046],
#        [-0.63132006, -0.68251014, -0.53896356, -1.2189962 ],
#        [ 0.8403385 ,  0.82914907,  0.80926216,  0.95258707],
#        [-1.125041  , -0.26385483, -0.99604464, -0.9907147 ],
#        [ 0.16035697,  0.21069707, -0.17954917, -0.03154697],
#        [ 1.6060926 ,  1.6145031 ,  1.5004398 ,  1.7669795 ],
#        [ 1.285495  ,  0.5649749 ,  1.1225042 ,  1.001341  ],
#        [ 0.26313028,  0.50146204, -0.02408387, -0.26001686],
#        [-0.86517125, -0.9368011 ,  0.18607377, -1.2323446 ],
#        [-1.5714148 , -1.5060921 , -2.1920552 , -1.4589181 ],
#        [ 0.7425473 ,  0.65806556,  1.0268557 ,  0.7613024 ],
#        [ 1.5682641 ,  1.6396012 ,  1.3915318 ,  1.461221  ],
#        [-0.40048447,  0.27561527, -0.53099364, -0.09526447],
#        [-0.01016958, -0.03946666,  0.09258608, -0.12865295],
#        [-0.5494249 , -0.5749161 , -0.74676836, -0.54879004],
#        [-1.3897821 , -1.7814094 , -1.3674772 , -1.7336428 ],
#        [-0.5720195 , -0.7022545 , -0.6739463 , -0.6751703 ],
#        [ 1.4821825 ,  1.4509313 ,  1.240365  ,  1.3654405 ],
#        [ 1.3275268 ,  1.6337436 ,  1.0353625 ,  1.1961111 ],
#        [-0.28257966, -0.22183335,  0.24996217,  0.09098024],
#        [-0.624929  , -1.418522  , -1.1213129 , -0.24260125],
#        [ 1.2022147 ,  1.2351747 ,  1.131957  ,  1.3222651 ],
#        [ 0.819049  ,  0.56940526,  0.71447134,  0.77199614],
#        [-0.04723184, -0.10689729, -0.17320254,  0.05275186],
#        [-0.52245855, -0.98744494, -0.56734353, -0.25175196],
#        [-0.9609791 , -1.2040979 , -0.58968663, -1.1082252 ],
#        [-0.4188268 , -0.899829  , -0.9317189 , -0.5706954 ],
#        [-1.7185596 , -0.94861454, -1.0588133 , -0.68220985],
#        [-0.8429083 ,  0.13447298, -0.53746665, -0.5479129 ],
#        [-0.8087298 , -0.609996  , -0.35366017, -0.880009  ],
#        [-0.08331169, -0.01896298, -0.0620985 , -0.14822313],
#        [ 0.19353956,  0.13345657,  0.11089113, -0.66354126],
#        [-0.02813749,  0.1474562 , -0.24342321,  0.7204922 ],
#        [ 0.45306027, -1.2280439 ,  0.56372166, -0.9971528 ],
#        [ 0.3252628 ,  0.771637  , -0.19910583,  0.16471513],
#        [-0.49392945, -0.5626479 , -0.22782691, -0.8033863 ],
#        [-0.72374916, -0.12304311, -1.0903476 , -0.38695678],
#        [ 0.89294297,  0.9971081 ,  1.3717375 ,  1.0562959 ]],
#       dtype=float32), array([-0.14170696, -0.00563763,  0.39330167, -0.07754607], dtype=float32)]
