# %% [markdown]
# # Práctica 2 – Aprendizaje Automático II
# ## DQN para el entorno LunarLander-v3
#
# ### Autores
#
# | Nombre | Correo |
# |--------|--------|
# | Julio Lucero | julio.lucero@alumnos.upm.es |
# | Nombre Apellido  | alumno2@universidad.es |

# %% [markdown]
# # Descripcion del Problema

# %% [markdown]
# # Librerias

# %%
# !pip install gymnasium[box2d] gymnasium[classic-control]

import gymnasium as gym
import numpy as np
from tensorflow import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import random
import math
